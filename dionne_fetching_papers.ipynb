# %% [markdown]
# # Fetching papers

# %% [markdown]
# Running the code below took around 2.5 minutes.

# %%
from pyalex import Works, Authors, Source, Institutions, Topics
import pandas as pd
import requests
import time 

BASE_URL = "https://api.openalex.org/works"


query = """
(
  "artificial intelligence" OR AI OR "machine learning" OR ML OR "deep learning" OR DL OR 
  "natural language processing" OR NLP OR "predictive modeling" OR "data mining" OR 
  "data science" OR "neural networks" OR "transformer models" OR "language models" OR 
  "recommendation systems" OR "generative AI" OR "unsupervised learning" OR "supervised learning"
)
AND
(
  pricing OR promotion OR discount OR "price optimization" OR "dynamic pricing" OR 
  "sales prediction" OR "revenue management" OR "price elasticity" OR "demand forecasting" OR 
  marketing OR "campaign optimization" OR "consumer behavior" OR "targeting" OR "personalization"
)
AND
(
  retail OR supermarket OR "large-scale distribution" OR GDO OR "grocery stores" OR 
  "e-commerce" OR ecommerce OR "supply chain" OR "consumer goods" OR "FMCG" OR 
  "wholesale" OR "shopping behavior" OR "omnichannel" OR "online retail" OR "brick and mortar"
)
"""


params = {
    "search": query,
    "filter": "from_publication_date:2014-01-01,to_publication_date:2024-12-31",
    "per_page": 200,
    "cursor": "*"
}
all_results = []
max_pages = 50  # Safety limit: remove this if you want everything

for i in range(max_pages):
    print(f"Fetching page {i+1}")
    response = requests.get(BASE_URL, params=params)
    if response.status_code != 200:
        print("Error:", response.status_code, response.text)
        break

    data = response.json()
    all_results.extend(data["results"])

    next_cursor = data.get("meta", {}).get("next_cursor")
    if not next_cursor:
        break  # No more pages
    params["cursor"] = next_cursor
    time.sleep(1)  # Optional: Avoid rate-limiting (max 10 requests/sec)

print(f"Total papers fetched: {len(all_results)}")
# Out:
# Fetching page 1
# Fetching page 2
# Fetching page 3
# Fetching page 4
# Fetching page 5
# Fetching page 6
# Fetching page 7
# Fetching page 8
# Fetching page 9
# Fetching page 10
# Fetching page 11
# Fetching page 12
# Fetching page 13
# Fetching page 14
# Fetching page 15
# Fetching page 16
# Fetching page 17
# Fetching page 18
# Fetching page 19
# Fetching page 20
# Fetching page 21
# Fetching page 22
# Fetching page 23
# Fetching page 24
# Fetching page 25
# Fetching page 26
# Fetching page 27
# Fetching page 28
# Fetching page 29
# Fetching page 30
# Fetching page 31
# Fetching page 32
# Fetching page 33
# Fetching page 34
# Fetching page 35
# Fetching page 36
# Fetching page 37
# Fetching page 38
# Fetching page 39
# Fetching page 40
# Fetching page 41
# Fetching page 42
# Fetching page 43
# Fetching page 44
# Fetching page 45
# Fetching page 46
# Fetching page 47
# Fetching page 48
# Fetching page 49
# Fetching page 50
# Total papers fetched: 10000

# %%
import json

# Check the first paper
first_paper = all_results[0]
print(json.dumps(first_paper, indent=2))
# Out:
# {
#   "id": "https://openalex.org/W3047327247",
#   "doi": "https://doi.org/10.1080/13675567.2020.1803246",
#   "title": "Machine learning demand forecasting and supply chain performance",
#   "display_name": "Machine learning demand forecasting and supply chain performance",
#   "relevance_score": 851.8783,
#   "publication_year": 2020,
#   "publication_date": "2020-08-04",
#   "ids": {
#     "openalex": "https://openalex.org/W3047327247",
#     "doi": "https://doi.org/10.1080/13675567.2020.1803246",
#     "mag": "3047327247"
#   },
#   "language": "en",
#   "primary_location": {
#     "is_oa": true,
#     "landing_page_url": "https://doi.org/10.1080/13675567.2020.1803246",
#     "pdf_url": null,
#     "source": {
#       "id": "https://openalex.org/S4210220312",
#       "display_name": "International Journal of Logistics Research and Applications",
#       "issn_l": "1367-5567",
#       "issn": [
#         "1367-5567",
#         "1469-848X"
#       ],
#       "is_oa": false,
#       "is_in_doaj": false,
#       "is_indexed_in_scopus": true,
#       "is_core": true,
#       "host_organization": "https://openalex.org/P4310320547",
#       "host_organization_name": "Taylor & Francis",
#       "host_organization_lineage": [
#         "https://openalex.org/P4310320547"
#       ],
#       "host_organization_lineage_names": [
#         "Taylor & Francis"
#       ],
#       "type": "journal"
#     },
#     "license": "cc-by",
#     "license_id": "https://openalex.org/licenses/cc-by",
#     "version": "publishedVersion",
#     "is_accepted": true,
#     "is_published": true
#   },
#   "type": "article",
#   "type_crossref": "journal-article",
#   "indexed_in": [
#     "crossref"
#   ],
#   "open_access": {
#     "is_oa": true,
#     "oa_status": "hybrid",
#     "oa_url": "https://doi.org/10.1080/13675567.2020.1803246",
#     "any_repository_has_fulltext": false
#   },
#   "authorships": [
#     {
#       "author_position": "first",
#       "author": {
#         "id": "https://openalex.org/A5109301691",
#         "display_name": "Javad Feizabadi",
#         "orcid": null
#       },
#       "institutions": [
#         {
#           "id": "https://openalex.org/I134138859",
#           "display_name": "Ministry of Science, Technology and Innovation",
#           "ror": "https://ror.org/012s3r374",
#           "country_code": "MY",
#           "type": "government",
#           "lineage": [
#             "https://openalex.org/I134138859"
#           ]
#         },
#         {
#           "id": "https://openalex.org/I63966007",
#           "display_name": "Massachusetts Institute of Technology",
#           "ror": "https://ror.org/042nb2s44",
#           "country_code": "US",
#           "type": "funder",
#           "lineage": [
#             "https://openalex.org/I63966007"
#           ]
#         }
#       ],
#       "countries": [
#         "MY",
#         "US"
#       ],
#       "is_corresponding": true,
#       "raw_author_name": "Javad Feizabadi",
#       "raw_affiliation_strings": [
#         "Malaysia Institute for Supply Chain Innovation, Massachusetts Institute of Technology (MIT) Global SCALE Network, Shah Alam, Malaysia"
#       ],
#       "affiliations": [
#         {
#           "raw_affiliation_string": "Malaysia Institute for Supply Chain Innovation, Massachusetts Institute of Technology (MIT) Global SCALE Network, Shah Alam, Malaysia",
#           "institution_ids": [
#             "https://openalex.org/I134138859",
#             "https://openalex.org/I63966007"
#           ]
#         }
#       ]
#     }
#   ],
#   "institution_assertions": [],
#   "countries_distinct_count": 2,
#   "institutions_distinct_count": 2,
#   "corresponding_author_ids": [
#     "https://openalex.org/A5109301691"
#   ],
#   "corresponding_institution_ids": [
#     "https://openalex.org/I134138859",
#     "https://openalex.org/I63966007"
#   ],
#   "apc_list": null,
#   "apc_paid": null,
#   "fwci": 10.438,
#   "has_fulltext": false,
#   "cited_by_count": 140,
#   "citation_normalized_percentile": {
#     "value": 0.999922,
#     "is_in_top_1_percent": true,
#     "is_in_top_10_percent": true
#   },
#   "cited_by_percentile_year": {
#     "min": 99,
#     "max": 100
#   },
#   "biblio": {
#     "volume": "25",
#     "issue": "2",
#     "first_page": "119",
#     "last_page": "142"
#   },
#   "is_retracted": false,
#   "is_paratext": false,
#   "primary_topic": {
#     "id": "https://openalex.org/T11918",
#     "display_name": "Forecasting Techniques and Applications",
#     "score": 0.9978,
#     "subfield": {
#       "id": "https://openalex.org/subfields/1803",
#       "display_name": "Management Science and Operations Research"
#     },
#     "field": {
#       "id": "https://openalex.org/fields/18",
#       "display_name": "Decision Sciences"
#     },
#     "domain": {
#       "id": "https://openalex.org/domains/2",
#       "display_name": "Social Sciences"
#     }
#   },
#   "topics": [
#     {
#       "id": "https://openalex.org/T11918",
#       "display_name": "Forecasting Techniques and Applications",
#       "score": 0.9978,
#       "subfield": {
#         "id": "https://openalex.org/subfields/1803",
#         "display_name": "Management Science and Operations Research"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/18",
#         "display_name": "Decision Sciences"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/2",
#         "display_name": "Social Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T11443",
#       "display_name": "Advanced Statistical Process Monitoring",
#       "score": 0.9826,
#       "subfield": {
#         "id": "https://openalex.org/subfields/1804",
#         "display_name": "Statistics, Probability and Uncertainty"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/18",
#         "display_name": "Decision Sciences"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/2",
#         "display_name": "Social Sciences"
#       }
#     },
#     {
#       "id": "https://openalex.org/T10328",
#       "display_name": "Supply Chain and Inventory Management",
#       "score": 0.9755,
#       "subfield": {
#         "id": "https://openalex.org/subfields/1404",
#         "display_name": "Management Information Systems"
#       },
#       "field": {
#         "id": "https://openalex.org/fields/14",
#         "display_name": "Business, Management and Accounting"
#       },
#       "domain": {
#         "id": "https://openalex.org/domains/2",
#         "display_name": "Social Sciences"
#       }
#     }
#   ],
#   "keywords": [
#     {
#       "id": "https://openalex.org/keywords/bullwhip-effect",
#       "display_name": "Bullwhip effect",
#       "score": 0.48185906
#     },
#     {
#       "id": "https://openalex.org/keywords/learning-effect",
#       "display_name": "Learning effect",
#       "score": 0.47173417
#     }
#   ],
#   "concepts": [
#     {
#       "id": "https://openalex.org/C108713360",
#       "wikidata": "https://www.wikidata.org/wiki/Q1824206",
#       "display_name": "Supply chain",
#       "level": 2,
#       "score": 0.83502656
#     },
#     {
#       "id": "https://openalex.org/C193809577",
#       "wikidata": "https://www.wikidata.org/wiki/Q3409300",
#       "display_name": "Demand forecasting",
#       "level": 2,
#       "score": 0.70300376
#     },
#     {
#       "id": "https://openalex.org/C2778869765",
#       "wikidata": "https://www.wikidata.org/wiki/Q6028363",
#       "display_name": "Inefficiency",
#       "level": 2,
#       "score": 0.6694984
#     },
#     {
#       "id": "https://openalex.org/C2779343474",
#       "wikidata": "https://www.wikidata.org/wiki/Q3109175",
#       "display_name": "Context (archaeology)",
#       "level": 2,
#       "score": 0.59307194
#     },
#     {
#       "id": "https://openalex.org/C41008148",
#       "wikidata": "https://www.wikidata.org/wiki/Q21198",
#       "display_name": "Computer science",
#       "level": 0,
#       "score": 0.5806479
#     },
#     {
#       "id": "https://openalex.org/C120330832",
#       "wikidata": "https://www.wikidata.org/wiki/Q166656",
#       "display_name": "Supply and demand",
#       "level": 2,
#       "score": 0.522236
#     },
#     {
#       "id": "https://openalex.org/C196083921",
#       "wikidata": "https://www.wikidata.org/wiki/Q7915758",
#       "display_name": "Variance (accounting)",
#       "level": 2,
#       "score": 0.5016575
#     },
#     {
#       "id": "https://openalex.org/C178595485",
#       "wikidata": "https://www.wikidata.org/wiki/Q1343909",
#       "display_name": "Bullwhip effect",
#       "level": 4,
#       "score": 0.48185906
#     },
#     {
#       "id": "https://openalex.org/C10431821",
#       "wikidata": "https://www.wikidata.org/wiki/Q6510174",
#       "display_name": "Learning effect",
#       "level": 2,
#       "score": 0.47173417
#     },
#     {
#       "id": "https://openalex.org/C44104985",
#       "wikidata": "https://www.wikidata.org/wiki/Q492886",
#       "display_name": "Supply chain management",
#       "level": 3,
#       "score": 0.418576
#     },
#     {
#       "id": "https://openalex.org/C90673727",
#       "wikidata": "https://www.wikidata.org/wiki/Q901718",
#       "display_name": "Product (mathematics)",
#       "level": 2,
#       "score": 0.41305006
#     },
#     {
#       "id": "https://openalex.org/C149782125",
#       "wikidata": "https://www.wikidata.org/wiki/Q160039",
#       "display_name": "Econometrics",
#       "level": 1,
#       "score": 0.37279773
#     },
#     {
#       "id": "https://openalex.org/C13736549",
#       "wikidata": "https://www.wikidata.org/wiki/Q4489420",
#       "display_name": "Industrial engineering",
#       "level": 1,
#       "score": 0.32699028
#     },
#     {
#       "id": "https://openalex.org/C162324750",
#       "wikidata": "https://www.wikidata.org/wiki/Q8134",
#       "display_name": "Economics",
#       "level": 0,
#       "score": 0.23602355
#     },
#     {
#       "id": "https://openalex.org/C21547014",
#       "wikidata": "https://www.wikidata.org/wiki/Q1423657",
#       "display_name": "Operations management",
#       "level": 1,
#       "score": 0.21862394
#     },
#     {
#       "id": "https://openalex.org/C175444787",
#       "wikidata": "https://www.wikidata.org/wiki/Q39072",
#       "display_name": "Microeconomics",
#       "level": 1,
#       "score": 0.1710608
#     },
#     {
#       "id": "https://openalex.org/C144133560",
#       "wikidata": "https://www.wikidata.org/wiki/Q4830453",
#       "display_name": "Business",
#       "level": 0,
#       "score": 0.16064283
#     },
#     {
#       "id": "https://openalex.org/C162853370",
#       "wikidata": "https://www.wikidata.org/wiki/Q39809",
#       "display_name": "Marketing",
#       "level": 1,
#       "score": 0.14852777
#     },
#     {
#       "id": "https://openalex.org/C127413603",
#       "wikidata": "https://www.wikidata.org/wiki/Q11023",
#       "display_name": "Engineering",
#       "level": 0,
#       "score": 0.14682993
#     },
#     {
#       "id": "https://openalex.org/C33923547",
#       "wikidata": "https://www.wikidata.org/wiki/Q395",
#       "display_name": "Mathematics",
#       "level": 0,
#       "score": 0.10997346
#     },
#     {
#       "id": "https://openalex.org/C151730666",
#       "wikidata": "https://www.wikidata.org/wiki/Q7205",
#       "display_name": "Paleontology",
#       "level": 1,
#       "score": 0.0
#     },
#     {
#       "id": "https://openalex.org/C2524010",
#       "wikidata": "https://www.wikidata.org/wiki/Q8087",
#       "display_name": "Geometry",
#       "level": 1,
#       "score": 0.0
#     },
#     {
#       "id": "https://openalex.org/C121955636",
#       "wikidata": "https://www.wikidata.org/wiki/Q4116214",
#       "display_name": "Accounting",
#       "level": 1,
#       "score": 0.0
#     },
#     {
#       "id": "https://openalex.org/C86803240",
#       "wikidata": "https://www.wikidata.org/wiki/Q420",
#       "display_name": "Biology",
#       "level": 0,
#       "score": 0.0
#     }
#   ],
#   "mesh": [],
#   "locations_count": 1,
#   "locations": [
#     {
#       "is_oa": true,
#       "landing_page_url": "https://doi.org/10.1080/13675567.2020.1803246",
#       "pdf_url": null,
#       "source": {
#         "id": "https://openalex.org/S4210220312",
#         "display_name": "International Journal of Logistics Research and Applications",
#         "issn_l": "1367-5567",
#         "issn": [
#           "1367-5567",
#           "1469-848X"
#         ],
#         "is_oa": false,
#         "is_in_doaj": false,
#         "is_indexed_in_scopus": true,
#         "is_core": true,
#         "host_organization": "https://openalex.org/P4310320547",
#         "host_organization_name": "Taylor & Francis",
#         "host_organization_lineage": [
#           "https://openalex.org/P4310320547"
#         ],
#         "host_organization_lineage_names": [
#           "Taylor & Francis"
#         ],
#         "type": "journal"
#       },
#       "license": "cc-by",
#       "license_id": "https://openalex.org/licenses/cc-by",
#       "version": "publishedVersion",
#       "is_accepted": true,
#       "is_published": true
#     }
#   ],
#   "best_oa_location": {
#     "is_oa": true,
#     "landing_page_url": "https://doi.org/10.1080/13675567.2020.1803246",
#     "pdf_url": null,
#     "source": {
#       "id": "https://openalex.org/S4210220312",
#       "display_name": "International Journal of Logistics Research and Applications",
#       "issn_l": "1367-5567",
#       "issn": [
#         "1367-5567",
#         "1469-848X"
#       ],
#       "is_oa": false,
#       "is_in_doaj": false,
#       "is_indexed_in_scopus": true,
#       "is_core": true,
#       "host_organization": "https://openalex.org/P4310320547",
#       "host_organization_name": "Taylor & Francis",
#       "host_organization_lineage": [
#         "https://openalex.org/P4310320547"
#       ],
#       "host_organization_lineage_names": [
#         "Taylor & Francis"
#       ],
#       "type": "journal"
#     },
#     "license": "cc-by",
#     "license_id": "https://openalex.org/licenses/cc-by",
#     "version": "publishedVersion",
#     "is_accepted": true,
#     "is_published": true
#   },
#   "sustainable_development_goals": [],
#   "grants": [],
#   "datasets": [],
#   "versions": [],
#   "referenced_works_count": 102,
#   "referenced_works": [
#     "https://openalex.org/W122374401",
#     "https://openalex.org/W145466897",
#     "https://openalex.org/W1519593622",
#     "https://openalex.org/W1532953897",
#     "https://openalex.org/W1557609506",
#     "https://openalex.org/W1595293901",
#     "https://openalex.org/W160021815",
#     "https://openalex.org/W1963833123",
#     "https://openalex.org/W1968603678",
#     "https://openalex.org/W1975602051",
#     "https://openalex.org/W1988277750",
#     "https://openalex.org/W1992880712",
#     "https://openalex.org/W1997754540",
#     "https://openalex.org/W1998418791",
#     "https://openalex.org/W1999325474",
#     "https://openalex.org/W2007367842",
#     "https://openalex.org/W2009329249",
#     "https://openalex.org/W2015147440",
#     "https://openalex.org/W2016554801",
#     "https://openalex.org/W2023114157",
#     "https://openalex.org/W2024421844",
#     "https://openalex.org/W2025224198",
#     "https://openalex.org/W2029038945",
#     "https://openalex.org/W2030902029",
#     "https://openalex.org/W2031869633",
#     "https://openalex.org/W2036384167",
#     "https://openalex.org/W2037889385",
#     "https://openalex.org/W2040640338",
#     "https://openalex.org/W2041706261",
#     "https://openalex.org/W2046242716",
#     "https://openalex.org/W2048665112",
#     "https://openalex.org/W2058057920",
#     "https://openalex.org/W2058739236",
#     "https://openalex.org/W2062546209",
#     "https://openalex.org/W2067092987",
#     "https://openalex.org/W2068244955",
#     "https://openalex.org/W2075645477",
#     "https://openalex.org/W2075910098",
#     "https://openalex.org/W2077663730",
#     "https://openalex.org/W2078309414",
#     "https://openalex.org/W2086706549",
#     "https://openalex.org/W2090007741",
#     "https://openalex.org/W2096175586",
#     "https://openalex.org/W2104925392",
#     "https://openalex.org/W2111793685",
#     "https://openalex.org/W2113362382",
#     "https://openalex.org/W2114840041",
#     "https://openalex.org/W2123479313",
#     "https://openalex.org/W2125066969",
#     "https://openalex.org/W2128269288",
#     "https://openalex.org/W2132720880",
#     "https://openalex.org/W2134070777",
#     "https://openalex.org/W2136886086",
#     "https://openalex.org/W2137671455",
#     "https://openalex.org/W2138170568",
#     "https://openalex.org/W2145856394",
#     "https://openalex.org/W2156146929",
#     "https://openalex.org/W2159491823",
#     "https://openalex.org/W2162848971",
#     "https://openalex.org/W2164683131",
#     "https://openalex.org/W2174890733",
#     "https://openalex.org/W2178204454",
#     "https://openalex.org/W2254323733",
#     "https://openalex.org/W2342948114",
#     "https://openalex.org/W2380935631",
#     "https://openalex.org/W2477834368",
#     "https://openalex.org/W2496180497",
#     "https://openalex.org/W2507508842",
#     "https://openalex.org/W2548345880",
#     "https://openalex.org/W2552660223",
#     "https://openalex.org/W2553942083",
#     "https://openalex.org/W2573254615",
#     "https://openalex.org/W259241460",
#     "https://openalex.org/W2753445311",
#     "https://openalex.org/W2773625660",
#     "https://openalex.org/W2783805549",
#     "https://openalex.org/W2787031726",
#     "https://openalex.org/W2787894218",
#     "https://openalex.org/W2794778778",
#     "https://openalex.org/W2804569679",
#     "https://openalex.org/W2808873517",
#     "https://openalex.org/W281130562",
#     "https://openalex.org/W2889059162",
#     "https://openalex.org/W2901657898",
#     "https://openalex.org/W2946015029",
#     "https://openalex.org/W2963312918",
#     "https://openalex.org/W2965853236",
#     "https://openalex.org/W303753577",
#     "https://openalex.org/W3111707824",
#     "https://openalex.org/W3122214176",
#     "https://openalex.org/W3122916300",
#     "https://openalex.org/W3123003249",
#     "https://openalex.org/W3123962622",
#     "https://openalex.org/W3126075123",
#     "https://openalex.org/W3168019185",
#     "https://openalex.org/W4229942792",
#     "https://openalex.org/W4237911197",
#     "https://openalex.org/W4250655305",
#     "https://openalex.org/W4252686346",
#     "https://openalex.org/W42668288",
#     "https://openalex.org/W4302438404",
#     "https://openalex.org/W52169070"
#   ],
#   "related_works": [
#     "https://openalex.org/W4313057686",
#     "https://openalex.org/W3161556095",
#     "https://openalex.org/W2501030226",
#     "https://openalex.org/W2391761644",
#     "https://openalex.org/W2378532152",
#     "https://openalex.org/W2377447009",
#     "https://openalex.org/W2376467364",
#     "https://openalex.org/W2353698110",
#     "https://openalex.org/W2093839928",
#     "https://openalex.org/W2050023151"
#   ],
#   "abstract_inverted_index": {
#     "In": [
#       0,
#       69
#     ],
#     "many": [
#       1
#     ],
#     "supply": [
#       2,
#       23,
#       65,
#       118
#     ],
#     "chains,": [
#       3
#     ],
#     "firms": [
#       4
#     ],
#     "staged": [
#       5
#     ],
#     "in": [
#       6,
#       20,
#       105
#     ],
#     "upstream": [
#       7
#     ],
#     "of": [
#       8,
#       61,
#       108
#     ],
#     "the": [
#       9,
#       44,
#       48,
#       57,
#       96,
#       106,
#       135
#     ],
#     "chain": [
#       10,
#       24,
#       66,
#       119
#     ],
#     "suffer": [
#       11
#     ],
#     "from": [
#       12,
#       16
#     ],
#     "variance": [
#       13
#     ],
#     "amplification": [
#       14
#     ],
#     "emanating": [
#       15
#     ],
#     "demand": [
#       17,
#       36,
#       73,
#       129
#     ],
#     "information": [
#       18
#     ],
#     "distortion": [
#       19
#     ],
#     "a": [
#       21,
#       112
#     ],
#     "multi-stage": [
#       22
#     ],
#     "and,": [
#       25
#     ],
#     "consequently,": [
#       26
#     ],
#     "their": [
#       27
#     ],
#     "operation": [
#       28
#     ],
#     "inefficiency.": [
#       29
#     ],
#     "Prior": [
#       30
#     ],
#     "research": [
#       31
#     ],
#     "suggest": [
#       32
#     ],
#     "that": [
#       33
#     ],
#     "employing": [
#       34
#     ],
#     "advanced": [
#       35
#     ],
#     "forecasting,": [
#       37
#     ],
#     "such": [
#       38
#     ],
#     "as": [
#       39,
#       63
#     ],
#     "machine": [
#       40,
#       78
#     ],
#     "learning,": [
#       41
#     ],
#     "could": [
#       42
#     ],
#     "mitigate": [
#       43
#     ],
#     "effect": [
#       45
#     ],
#     "and": [
#       46,
#       59,
#       82,
#       90,
#       103,
#       111,
#       127,
#       137
#     ],
#     "improve": [
#       47
#     ],
#     "performance;": [
#       49
#     ],
#     "however,": [
#       50
#     ],
#     "it": [
#       51
#     ],
#     "is": [
#       52,
#       56,
#       85
#     ],
#     "less": [
#       53
#     ],
#     "known": [
#       54
#     ],
#     "what": [
#       55
#     ],
#     "extent": [
#       58
#     ],
#     "magnitude": [
#       60
#     ],
#     "savings": [
#       62
#     ],
#     "tangible": [
#       64
#     ],
#     "performance": [
#       67,
#       120
#     ],
#     "outcomes.": [
#       68
#     ],
#     "this": [
#       70
#     ],
#     "research,": [
#       71
#     ],
#     "hybrid": [
#       72
#     ],
#     "forecasting": [
#       74,
#       130
#     ],
#     "methods": [
#       75
#     ],
#     "grounded": [
#       76
#     ],
#     "on": [
#       77
#     ],
#     "learning": [
#       79
#     ],
#     "i.e.": [
#       80
#     ],
#     "ARIMAX": [
#       81
#     ],
#     "Neural": [
#       83
#     ],
#     "Network": [
#       84
#     ],
#     "developed.": [
#       86
#     ],
#     "Both": [
#       87
#     ],
#     "time": [
#       88
#     ],
#     "series": [
#       89
#     ],
#     "explanatory": [
#       91
#     ],
#     "factors": [
#       92
#     ],
#     "are": [
#       93,
#       139
#     ],
#     "feed": [
#       94
#     ],
#     "into": [
#       95
#     ],
#     "developed": [
#       97
#     ],
#     "method.": [
#       98
#     ],
#     "The": [
#       99,
#       115,
#       132
#     ],
#     "method": [
#       100
#     ],
#     "was": [
#       101
#     ],
#     "applied": [
#       102
#     ],
#     "evaluated": [
#       104
#     ],
#     "context": [
#       107
#     ],
#     "functional": [
#       109
#     ],
#     "product": [
#       110
#     ],
#     "steel": [
#       113
#     ],
#     "manufacturer.": [
#       114
#     ],
#     "statistically": [
#       116
#     ],
#     "significant": [
#       117
#     ],
#     "improvement": [
#       121
#     ],
#     "differences": [
#       122
#     ],
#     "were": [
#       123
#     ],
#     "found": [
#       124
#     ],
#     "across": [
#       125
#     ],
#     "traditional": [
#       126
#     ],
#     "ML-based": [
#       128
#     ],
#     "methods.": [
#       131
#     ],
#     "implications": [
#       133
#     ],
#     "for": [
#       134
#     ],
#     "theory": [
#       136
#     ],
#     "practice": [
#       138
#     ],
#     "also": [
#       140
#     ],
#     "presented.": [
#       141
#     ]
#   },
#   "abstract_inverted_index_v3": null,
#   "cited_by_api_url": "https://api.openalex.org/works?filter=cites:W3047327247",
#   "counts_by_year": [
#     {
#       "year": 2025,
#       "cited_by_count": 13
#     },
#     {
#       "year": 2024,
#       "cited_by_count": 59
#     },
#     {
#       "year": 2023,
#       "cited_by_count": 38
#     },
#     {
#       "year": 2022,
#       "cited_by_count": 22
#     },
#     {
#       "year": 2021,
#       "cited_by_count": 4
#     },
#     {
#       "year": 2020,
#       "cited_by_count": 2
#     }
#   ],
#   "updated_date": "2025-03-19T09:40:40.806765",
#   "created_date": "2020-08-10"
# }

# %%
# Make sure you have at least one result
if all_results:
    first_paper = all_results[0]
    pub_year = first_paper.get("publication_year", "N/A")
    print(f"Publication year of the first paper: {pub_year}")
else:
    print("No papers found.")
# Out:
# Publication year of the first paper: 2020

# %%
file_path_json = "/Users/dionnespaltman/Desktop/Luiss /Data Science in Action/Project/openalex_results.json"
file_path_csv = "/Users/dionnespaltman/Desktop/Luiss /Data Science in Action/Project/openalex_results.csv"

import pandas as pd
import json

# Save data in both CSV and JSON formats

# Convert to DataFrame for flat/tabular structure (good for CSV export)
df = pd.DataFrame(all_results)

# Save as CSV
# CSV is ideal for quick inspection, Excel use, or working with pandas.
# However, it will flatten the structure and drop nested fields like 'authorships'.
df.to_csv(file_path_csv, index=False)
print("Data saved to openalex_results.csv")

# Save as JSON
# JSON retains the full nested structure of each entry (e.g., authorship, abstract index, locations),
# which is essential for any downstream processing like recommendation systems or NLP tasks.
with open(file_path_json, "w") as f:
    json.dump(all_results, f, indent=2)
print("Data saved to openalex_results.json")
# Out:
# Data saved to openalex_results.csv
# Data saved to openalex_results.json
