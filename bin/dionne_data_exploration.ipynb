# %% [markdown]
# # Data exploration

# %%
import pandas as pd 

file_path_json = "/Users/dionnespaltman/Desktop/Luiss /Data Science in Action/Project/openalex_results.json"
file_path_csv = "/Users/dionnespaltman/Desktop/Luiss /Data Science in Action/Project/openalex_results.csv"

# Load the data
df = pd.read_csv(file_path_csv)

# %%
# Inspect data 
display(df.head())
# Out:
#                                  id  \
# 0  https://openalex.org/W3047327247
# 1  https://openalex.org/W3024362711
# 2  https://openalex.org/W2923129012
# 3  https://openalex.org/W2980994438
# 4  https://openalex.org/W4387379065
#
#                                                 doi  \
# 0     https://doi.org/10.1080/13675567.2020.1803246
# 1                https://doi.org/10.3390/su12104035
# 2              https://doi.org/10.1155/2019/9067367
# 3  https://doi.org/10.1016/j.ijforecast.2019.07.001
# 4     https://doi.org/10.1080/08874417.2023.2261010
#
#                                                title  \
# 0  Machine learning demand forecasting and supply...
# 1  Influences of the Industry 4.0 Revolution on t...
# 2  An Improved Demand Forecasting Model Using Dee...
# 3  DeepAR: Probabilistic forecasting with autoreg...
# 4  The Potential of Generative Artificial Intelli...
#
#                                         display_name  relevance_score  \
# 0  Machine learning demand forecasting and supply...         851.8783
# 1  Influences of the Industry 4.0 Revolution on t...         754.7955
# 2  An Improved Demand Forecasting Model Using Dee...         726.1050
# 3  DeepAR: Probabilistic forecasting with autoreg...         693.0750
# 4  The Potential of Generative Artificial Intelli...         688.9533
#
#    publication_year publication_date  \
# 0              2020       2020-08-04
# 1              2020       2020-05-14
# 2              2019       2019-01-01
# 3              2019       2019-10-19
# 4              2023       2023-10-05
#
#                                                  ids language  \
# 0  {'openalex': 'https://openalex.org/W3047327247...       en
# 1  {'openalex': 'https://openalex.org/W3024362711...       en
# 2  {'openalex': 'https://openalex.org/W2923129012...       en
# 3  {'openalex': 'https://openalex.org/W2980994438...       en
# 4  {'openalex': 'https://openalex.org/W4387379065...       en
#
#                                     primary_location  ...  \
# 0  {'is_oa': True, 'landing_page_url': 'https://d...  ...
# 1  {'is_oa': True, 'landing_page_url': 'https://d...  ...
# 2  {'is_oa': True, 'landing_page_url': 'https://d...  ...
# 3  {'is_oa': True, 'landing_page_url': 'https://d...  ...
# 4  {'is_oa': False, 'landing_page_url': 'https://...  ...
#
#                                     referenced_works  \
# 0  ['https://openalex.org/W122374401', 'https://o...
# 1  ['https://openalex.org/W1560042744', 'https://...
# 2  ['https://openalex.org/W124243540', 'https://o...
# 3  ['https://openalex.org/W129305155', 'https://o...
# 4  ['https://openalex.org/W2772633599', 'https://...
#
#                                        related_works  \
# 0  ['https://openalex.org/W4313057686', 'https://...
# 1  ['https://openalex.org/W648638662', 'https://o...
# 2  ['https://openalex.org/W4375867731', 'https://...
# 3  ['https://openalex.org/W3188413760', 'https://...
# 4  ['https://openalex.org/W4380551139', 'https://...
#
#                              abstract_inverted_index  \
# 0  {'In': [0, 69], 'many': [1], 'supply': [2, 23,...
# 1  {'Automation': [0], 'and': [1, 16, 23, 63, 101...
# 2  {'Demand': [0], 'forecasting': [1, 36, 58, 79,...
# 3  {'Probabilistic': [0], 'forecasting,': [1], 'i...
# 4  {'ABSTRACTIn': [0], 'a': [1, 86, 126], 'short'...
#
#   abstract_inverted_index_v3  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
#
#                                     cited_by_api_url  \
# 0  https://api.openalex.org/works?filter=cites:W3...
# 1  https://api.openalex.org/works?filter=cites:W3...
# 2  https://api.openalex.org/works?filter=cites:W2...
# 3  https://api.openalex.org/works?filter=cites:W2...
# 4  https://api.openalex.org/works?filter=cites:W4...
#
#                                       counts_by_year  \
# 0  [{'year': 2025, 'cited_by_count': 13}, {'year'...
# 1  [{'year': 2025, 'cited_by_count': 13}, {'year'...
# 2  [{'year': 2025, 'cited_by_count': 4}, {'year':...
# 3  [{'year': 2025, 'cited_by_count': 57}, {'year'...
# 4  [{'year': 2025, 'cited_by_count': 46}, {'year'...
#
#                  updated_date  created_date fulltext_origin  \
# 0  2025-03-19T09:40:40.806765    2020-08-10             NaN
# 1  2025-03-27T13:03:33.223437    2020-05-21             pdf
# 2  2025-03-23T10:02:26.057098    2019-04-01             pdf
# 3  2025-03-27T11:10:07.481385    2019-10-25             NaN
# 4  2025-03-23T10:47:46.228229    2023-10-06             pdf
#
#   is_authors_truncated
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 53 columns]

# %%
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 53 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              10000 non-null  object
#  1   doi                             9845 non-null   object
#  2   title                           9998 non-null   object
#  3   display_name                    9998 non-null   object
#  4   relevance_score                 10000 non-null  float64
#  5   publication_year                10000 non-null  int64
#  6   publication_date                10000 non-null  object
#  7   ids                             10000 non-null  object
#  8   language                        9995 non-null   object
#  9   primary_location                9995 non-null   object
#  10  type                            10000 non-null  object
#  11  type_crossref                   10000 non-null  object
#  12  indexed_in                      10000 non-null  object
#  13  open_access                     10000 non-null  object
#  14  authorships                     10000 non-null  object
#  15  institution_assertions          10000 non-null  object
#  16  countries_distinct_count        10000 non-null  int64
#  17  institutions_distinct_count     10000 non-null  int64
#  18  corresponding_author_ids        10000 non-null  object
#  19  corresponding_institution_ids   10000 non-null  object
#  20  apc_list                        4787 non-null   object
#  21  apc_paid                        2739 non-null   object
#  22  fwci                            9473 non-null   float64
#  23  has_fulltext                    10000 non-null  bool
#  24  cited_by_count                  10000 non-null  int64
#  25  citation_normalized_percentile  9967 non-null   object
#  26  cited_by_percentile_year        10000 non-null  object
#  27  biblio                          10000 non-null  object
#  28  is_retracted                    10000 non-null  bool
#  29  is_paratext                     10000 non-null  bool
#  30  primary_topic                   9981 non-null   object
#  31  topics                          10000 non-null  object
#  32  keywords                        10000 non-null  object
#  33  concepts                        10000 non-null  object
#  34  mesh                            10000 non-null  object
#  35  locations_count                 10000 non-null  int64
#  36  locations                       10000 non-null  object
#  37  best_oa_location                7137 non-null   object
#  38  sustainable_development_goals   10000 non-null  object
#  39  grants                          10000 non-null  object
#  40  datasets                        10000 non-null  object
#  41  versions                        10000 non-null  object
#  42  referenced_works_count          10000 non-null  int64
#  43  referenced_works                10000 non-null  object
#  44  related_works                   10000 non-null  object
#  45  abstract_inverted_index         8317 non-null   object
#  46  abstract_inverted_index_v3      0 non-null      float64
#  47  cited_by_api_url                10000 non-null  object
#  48  counts_by_year                  10000 non-null  object
#  49  updated_date                    10000 non-null  object
#  50  created_date                    10000 non-null  object
#  51  fulltext_origin                 7685 non-null   object
#  52  is_authors_truncated            3 non-null      object
# dtypes: bool(3), float64(3), int64(6), object(41)
# memory usage: 3.8+ MB
# None

# %%
# Get count of missing values
print(df.isnull().sum())
# Out:
# id                                    0
# doi                                 155
# title                                 2
# display_name                          2
# relevance_score                       0
# publication_year                      0
# publication_date                      0
# ids                                   0
# language                              5
# primary_location                      5
# type                                  0
# type_crossref                         0
# indexed_in                            0
# open_access                           0
# authorships                           0
# institution_assertions                0
# countries_distinct_count              0
# institutions_distinct_count           0
# corresponding_author_ids              0
# corresponding_institution_ids         0
# apc_list                           5213
# apc_paid                           7261
# fwci                                527
# has_fulltext                          0
# cited_by_count                        0
# citation_normalized_percentile       33
# cited_by_percentile_year              0
# biblio                                0
# is_retracted                          0
# is_paratext                           0
# primary_topic                        19
# topics                                0
# keywords                              0
# concepts                              0
# mesh                                  0
# locations_count                       0
# locations                             0
# best_oa_location                   2863
# sustainable_development_goals         0
# grants                                0
# datasets                              0
# versions                              0
# referenced_works_count                0
# referenced_works                      0
# related_works                         0
# abstract_inverted_index            1683
# abstract_inverted_index_v3        10000
# cited_by_api_url                      0
# counts_by_year                        0
# updated_date                          0
# created_date                          0
# fulltext_origin                    2315
# is_authors_truncated               9997
# dtype: int64
