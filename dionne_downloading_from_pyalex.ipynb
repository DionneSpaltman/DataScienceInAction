# %% [markdown]
# # Downloading papers using PyAlex

# %% [markdown]
# Some suggestions from the first checkpoint:
# - Synonyms, broaden search on openalex
# - Wikipedia one is not the best
# - Uncased is the best
# - Around 1000

# %%
pip install pyalex pandas
# Out:
# Collecting pyalex
#   Downloading pyalex-0.18-py3-none-any.whl (13 kB)
# Requirement already satisfied: pandas in /Users/dionnespaltman/anaconda3/lib/python3.10/site-packages (1.5.3)
# Requirement already satisfied: requests in /Users/dionnespaltman/anaconda3/lib/python3.10/site-packages (from pyalex) (2.28.1)
# Requirement already satisfied: urllib3 in /Users/dionnespaltman/anaconda3/lib/python3.10/site-packages (from pyalex) (1.26.14)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/dionnespaltman/anaconda3/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in /Users/dionnespaltman/anaconda3/lib/python3.10/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in /Users/dionnespaltman/anaconda3/lib/python3.10/site-packages (from pandas) (2022.7)
# Requirement already satisfied: six>=1.5 in /Users/dionnespaltman/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dionnespaltman/anaconda3/lib/python3.10/site-packages (from requests->pyalex) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/dionnespaltman/anaconda3/lib/python3.10/site-packages (from requests->pyalex) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dionnespaltman/anaconda3/lib/python3.10/site-packages (from requests->pyalex) (2023.7.22)
# Installing collected packages: pyalex
# Successfully installed pyalex-0.18
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from pyalex import Works, Authors, Sources, Institutions, Topics

# %%
# Test query: Fetching 5 recent papers related to AI
sample_papers = Works().search("artificial intelligence").get(5)

# Print one sample paper
# print(sample_papers[0])

# Test query worked
# Out:
# /var/folders/_4/nzq6mygj7j71_l3z_c9kc7wr0000gn/T/ipykernel_47632/1425043748.py:2: DeprecationWarning: return_meta is deprecated, call .meta on the result
#   sample_papers = Works().search("artificial intelligence").get(5)

# %% [markdown]
# Let's define our search criteria now that our test query worked.
#
# Topic: AI for pricing and promotion for GDO
#
# Date Range: Last 10 years (2014-2024)
#
# Fields to extract:
# - id: ArXiv ID
# - submitter: Who submitted the paper
# - authors: Authors of the paper
# - title: Title of the paper
# - comments: Additional info (e.g., number of pages and figures)
# - Journ-ref: Information about the journal
# - doi: Digital Object Identifier
# - abstract: The abstract of the paper
# - versions: A version history
#
# Useful links: https://docs.openalex.org/api-entities/entities-overview and https://github.com/J535D165/pyalex

# %%
# First search parameters 
# Define search parameters
# query = "((artificial intelligence OR AI) AND (pricing OR promotion)) AND (retail OR supermarkets OR 'large-scale distribution' OR GDO)"
# Got 25 articles 

# # Define broader search parameters
# query = """
# (
#   (artificial intelligence OR AI OR "machine learning" OR "deep learning" OR "natural language processing" OR "predictive analytics")
#   AND
#   (pricing OR promotion OR discount OR "price optimization" OR "sales forecasting" OR marketing)
# )
# AND
# (
#   retail OR supermarket OR "large-scale distribution" OR GDO OR "supply chain" OR ecommerce OR "FMCG" OR grocery OR commerce
# )
# """
# Still got 25 articles? 

# Even broader query
query = """
(
  "artificial intelligence" OR AI OR "machine learning" OR ML OR "deep learning" OR DL OR 
  "natural language processing" OR NLP OR "predictive modeling" OR "data mining" OR 
  "data science" OR "neural networks" OR "transformer models" OR "language models" OR 
  "recommendation systems" OR "generative AI" OR "unsupervised learning" OR "supervised learning"
)
AND
(
  pricing OR promotion OR discount OR "price optimization" OR "dynamic pricing" OR 
  "sales prediction" OR "revenue management" OR "price elasticity" OR "demand forecasting" OR 
  marketing OR "campaign optimization" OR "consumer behavior" OR "targeting" OR "personalization"
)
AND
(
  retail OR supermarket OR "large-scale distribution" OR GDO OR "grocery stores" OR 
  "e-commerce" OR ecommerce OR "supply chain" OR "consumer goods" OR "FMCG" OR 
  "wholesale" OR "shopping behavior" OR "omnichannel" OR "online retail" OR "brick and mortar"
)
"""


# Search parameters 
year_start = 2014
year_end = 2024

# Fetch papers from OpenAlex
papers = Works().search(query).filter(from_publication_date=f"{year_start}-01-01",to_publication_date=f"{year_end}-12-31").get()

# Function to reconstruct abstracts if stored in abstract_inverted_index format
def reconstruct_abstract(abstract_index):
    if not abstract_index:
        return None
    words = []
    for key, positions in sorted(abstract_index.items(), key=lambda x: min(x[1])):
        words.append(key)
    return " ".join(words)

# Extract relevant information safely
data = []
for paper in papers:
    primary_location = paper.get("primary_location", {})  # Handle missing journal info
    source = primary_location.get("source")  # Might be None
    source_name = source["display_name"] if source else "Unknown"
    
    data.append({
        "id": paper.get("id"),  # ArXiv ID or OpenAlex ID
        "submitter": paper.get("submitter"),  # Who submitted the paper (if available)
        "authors": ", ".join([author["author"]["display_name"] 
                              for author in paper.get("authorships", []) 
                              if author.get("author")]),
        "title": paper.get("title"),
        "comments": paper.get("comments"),  # Additional info (e.g., pages, figures)
        "journ_ref": paper.get("journal_reference"),  # Journal reference info, if available
        "doi": paper.get("doi"),  # Digital Object Identifier
        "abstract": reconstruct_abstract(paper.get("abstract_inverted_index")),
        "versions": paper.get("versions"),  # Version history
        "year": paper.get("publication_year"),
        "journal": source_name,  # Journal name extracted from the source
        "keywords": paper.get("keywords", []),
        "topics": [topic["display_name"] for topic in paper.get("topics", [])],
    })

# Convert to DataFrame
df = pd.DataFrame(data)

# %% [markdown]
# Something is going wrong with the code, because we're getting very little articles.
# - With query "AI AND (pricing OR promotion) AND GDO" we get 21 articles.
# - With query "AI AND pricing AND promotion AND GDO" we get 5 articles.
# - With query "((artificial intelligence OR AI) AND (pricing OR promotion)) AND (retail OR supermarkets OR 'large-scale distribution' OR GDO)" we get 25 articles.
#
# Roughly speaking, how many articles should we be able to retrieve?
#
# What is GDO?
# GDO stands for "Grande Distribuzione Organizzata." In English, it is often translated as "organized large-scale distribution" or "organized retail," referring to large retail chains such as supermarkets and hypermarkets.

# %% [markdown]
# The previous code was wrong because it kept getting stuck on the first page.

# %%
# run this in your terminal 
# pip install pyalex

# %%
# !pip install pyalex
# Out:
# Requirement already satisfied: pyalex in /Users/dionnespaltman/anaconda3/lib/python3.10/site-packages (0.18)
# Requirement already satisfied: urllib3 in /Users/dionnespaltman/anaconda3/lib/python3.10/site-packages (from pyalex) (1.26.14)
# Requirement already satisfied: requests in /Users/dionnespaltman/anaconda3/lib/python3.10/site-packages (from pyalex) (2.28.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dionnespaltman/anaconda3/lib/python3.10/site-packages (from requests->pyalex) (2023.7.22)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/dionnespaltman/anaconda3/lib/python3.10/site-packages (from requests->pyalex) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dionnespaltman/anaconda3/lib/python3.10/site-packages (from requests->pyalex) (3.4)

# %%
# from pyalex import Works
# import pandas as pd
# import os

# # Set polite OpenAlex usage email
# os.environ["OPENALEX_EMAIL"] = "your.email@example.com"

# # Search parameters
# query = "((artificial intelligence OR AI) AND (pricing OR promotion)) AND (retail OR supermarkets OR 'large-scale distribution' OR GDO)"
# year_start = 2014
# year_end = 2024

# # Paginate manually
# cursor = "*"
# per_page = 50
# max_results = 500  # optional limit
# retrieved = 0
# data = []

# while cursor and retrieved < max_results:
#     response = Works().filter(
#         search=query,
#         from_publication_date=f"{year_start}-01-01",
#         to_publication_date=f"{year_end}-12-31"
#     ).paginate(per_page=per_page, cursor=cursor)

#     results = response['results']
#     cursor = response.get('meta', {}).get('next_cursor')
    
#     for paper in results:
#         def reconstruct_abstract(abstract_index):
#             if not abstract_index:
#                 return None
#             words = []
#             for key, positions in sorted(abstract_index.items(), key=lambda x: min(x[1])):
#                 words.append(key)
#             return " ".join(words)

#         venue = paper.get("host_venue", {})
#         source_name = venue.get("display_name", "Unknown")

#         data.append({
#             "id": paper.get("id"),
#             "title": paper.get("title"),
#             "abstract": reconstruct_abstract(paper.get("abstract_inverted_index")),
#             "authors": ", ".join([a["author"]["display_name"] for a in paper.get("authorships", []) if "author" in a]),
#             "year": paper.get("publication_year"),
#             "journal": source_name,
#             "doi": paper.get("doi"),
#             "topics": [t["display_name"] for t in paper.get("topics", [])],
#         })

#         retrieved += 1
#         if retrieved >= max_results:
#             break

# # Convert to DataFrame
# df = pd.DataFrame(data)
# print(f"✅ Total articles retrieved: {len(df)}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 27
#      20 while cursor and retrieved < max_results:
#      21     response = Works().filter(
#      22         search=query,
#      23         from_publication_date=f"{year_start}-01-01",
#      24         to_publication_date=f"{year_end}-12-31"
#      25     ).paginate(per_page=per_page, cursor=cursor)
# ---> 27     results = response['results']
#      28     cursor = response.get('meta', {}).get('next_cursor')
#      30     for paper in results:
#
# TypeError: 'Paginator' object is not subscriptable

# %%
# Display the number of articles in the dataframe
num_articles = len(df)
num_articles
# Out:
# 25

# %%
display(df)
# Out:
#                                   id submitter  \
# 0   https://openalex.org/W1901616594      None
# 1   https://openalex.org/W3089252064      None
# 2   https://openalex.org/W4220820301      None
# 3   https://openalex.org/W4387379065      None
# 4   https://openalex.org/W2964362517      None
# 5   https://openalex.org/W4386077567      None
# 6   https://openalex.org/W3007552940      None
# 7   https://openalex.org/W3109960748      None
# 8   https://openalex.org/W2913100501      None
# 9   https://openalex.org/W3202393140      None
# 10  https://openalex.org/W3208733127      None
# 11  https://openalex.org/W2945904062      None
# 12  https://openalex.org/W4385795267      None
# 13  https://openalex.org/W3003326204      None
# 14  https://openalex.org/W4235224114      None
# 15  https://openalex.org/W2944828013      None
# 16  https://openalex.org/W2944475534      None
# 17  https://openalex.org/W4224257787      None
# 18  https://openalex.org/W3034283122      None
# 19  https://openalex.org/W4200488781      None
# 20  https://openalex.org/W2972160171      None
# 21  https://openalex.org/W3157966460      None
# 22  https://openalex.org/W4200146754      None
# 23  https://openalex.org/W3115674532      None
# 24  https://openalex.org/W4205903454      None
#
#                                               authors  \
# 0                  Michael I. Jordan, Tom M. Mitchell
# 1   Reza Toorajipour, Vahid Sohrabpour, Ali Nazarp...
# 2                                      Jeffrey Dastin
# 3   Keng‐Boon Ooi, Garry Wei‐Han Tan, Mostafa Al‐E...
# 4   Rupa Dash, Mark E. McMurtrey, Carl Rebman, Upe...
# 5   Hanadi A. Salhab, Mahmoud Allahham, Ibrahim A....
# 6   Anandakumar Haldorai, Suriya Murugan, Arulmuru...
# 7   Vahid Sohrabpour, Pejvak Oghazi, Reza Toorajip...
# 8   K.H. Leung, Chris Luk, K.L. Choy, H.Y. Lam, C....
# 9   Saurabh Sharma, Vijay Kumar Gahlawat, Kumar Ra...
# 10  Raffaele Filieri, Elettra D’Amico, Alessandro ...
# 11                      Felix Weber, Reinhard Schütte
# 12                                    Bharati Rathore
# 13  Rajesh Gupta, Sudeep Tanwar, Fadi Al‐Turjman, ...
# 14  Arunangshu Giri, Satakshi Chatterjee, Pradip P...
# 15  Christina A. Roberto, Hannah G. Lawman, Michae...
# 16                                   Stanislav Ivanov
# 17  Pei-San Lo, Yogesh K. Dwivedi, Garry Wei‐Han T...
# 18  Dimitra Samara, Ioannis Magnisalis, Vassilios ...
# 19  Jyoti Rana, Loveleen Gaur, Gurmeet Singh, Usam...
# 20      Song Xia, Shiqi Yang, Ziqing Huang, Tao Huang
# 21  P. S. Varsha, Shahriar Akter, Amit Kumar, Saik...
# 22                                 Moaiad Ahmad Khder
# 23  Hyunkyeong Hwang, Ah-Yun Yoon, Hyun-Koo Kang, ...
# 24  Jaydip Sen, Sidra Mehtab, Rajdeep Sen, Abhishe...
#
#                                                 title comments journ_ref  \
# 0   Machine learning: Trends, perspectives, and pr...     None      None
# 1   Artificial intelligence in supply chain manage...     None      None
# 2   Amazon Scraps Secret AI Recruiting Tool that S...     None      None
# 3   The Potential of Generative Artificial Intelli...     None      None
# 4   Application of Artificial Intelligence in Auto...     None      None
# 5   Inventory competition, artificial intelligence...     None      None
# 6   Evolution, challenges, and application of inte...     None      None
# 7   Export sales forecasting using artificial inte...     None      None
# 8   A B2B flexible pricing decision support system...     None      None
# 9   Sustainable Innovations in the Food Industry t...     None      None
# 10  Artificial intelligence (AI) for tourism: an E...     None      None
# 11  State-of-the-art and adoption of artificial in...     None      None
# 12  Artificial Intelligence in Sustainable Fashion...     None      None
# 13  Smart Contract Privacy Protection Using AI in ...     None      None
# 14  Determining the Impact of Artificial Intellige...     None      None
# 15  Association of a Beverage Tax on Sugar-Sweeten...     None      None
# 16  Ultimate transformation: How will automation t...     None      None
# 17  Why do consumers buy impulsively during live s...     None      None
# 18  Artificial intelligence and big data in touris...     None      None
# 19  Reinforcing customer journey through artificia...     None      None
# 20  The Application of Artificial Intelligence in ...     None      None
# 21  The Impact of Artificial Intelligence on Branding     None      None
# 22  Web Scraping or Web Crawling: State of Art, Te...     None      None
# 23  Retail Electricity Pricing Strategy via an Art...     None      None
# 24  Machine Learning - Algorithms, Models and Appl...     None      None
#
#                                                 doi  \
# 0           https://doi.org/10.1126/science.aaa8415
# 1     https://doi.org/10.1016/j.jbusres.2020.09.009
# 2          https://doi.org/10.1201/9781003278290-44
# 3     https://doi.org/10.1080/08874417.2023.2261010
# 4          https://doi.org/10.33423/jsis.v14i3.2105
# 5         https://doi.org/10.5267/j.uscm.2023.8.009
# 6                 https://doi.org/10.1002/cae.22217
# 7    https://doi.org/10.1016/j.techfore.2020.120480
# 8     https://doi.org/10.1080/00207543.2019.1566674
# 9          https://doi.org/10.3390/logistics5040066
# 10       https://doi.org/10.1108/ijchm-02-2021-0220
# 11        https://doi.org/10.1108/dprg-09-2018-0050
# 12      https://doi.org/10.56614/eiprmj.v8i2y19.363
# 13      https://doi.org/10.1109/access.2020.2970576
# 14      https://doi.org/10.35940/ijeat.f9030.088619
# 15           https://doi.org/10.1001/jama.2019.4249
# 16             https://doi.org/10.1515/tw-2019-0003
# 17    https://doi.org/10.1016/j.jbusres.2022.04.013
# 18        https://doi.org/10.1108/jhtt-12-2018-0118
# 19       https://doi.org/10.1108/ijoem-08-2021-1214
# 20  https://doi.org/10.1088/1742-6596/1302/3/032030
# 21       https://doi.org/10.4018/jgim.20210701.oa10
# 22        https://doi.org/10.15849/ijasca.211128.11
# 23      https://doi.org/10.1109/access.2020.3048048
# 24         https://doi.org/10.5772/intechopen.94615
#
#                                              abstract  \
# 0   Machine learning addresses the question of how...
# 1   This paper seeks to identify the contributions...
# 2   Automation has been key to Amazon's e-commerce...
# 3   ABSTRACTIn a short span of time since its intr...
# 4   A well-functioning supply chain is a key to su...
# 5   This research examines the synergistic influen...
# 6   Abstract Artificial intelligence (AI) aims at ...
# 7   Sales forecasting is important in production a...
# 8   In the era of digitalisation, e-commerce retai...
# 9   The agri-food sector is an endless source of e...
# 10  Purpose The travel and tourism industry (TTI) ...
# 11  Purpose In the most abstract way, artificial i...
# 12  The rise of artificial intelligence (AI) has v...
# 13  Applications of Blockchain (BC) technology and...
# 14  In this age of digitization, technology is evo...
# 15  Policy makers have implemented beverage taxes ...
# 16  Abstract Companies from the travel, tourism an...
# 17  The power of livestreaming commerce to rake in...
# 18  Purpose This paper aims to research, identify ...
# 19  Purpose This study defines a three-angled rese...
# 20  Abstract With the rapid development of science...
# 21  Understanding the growth paths of artificial i...
# 22  Web scraping or web crawling refers to the pro...
# 23  The distribution company (DISCO) determines op...
# 24  Machine learning (ML) is the ability of a syst...
#
#                               versions  year  \
# 0                                   []  2015
# 1                                   []  2020
# 2                                   []  2022
# 3                                   []  2023
# 4                                   []  2019
# 5                                   []  2023
# 6                                   []  2020
# 7                                   []  2020
# 8                                   []  2019
# 9                                   []  2021
# 10                                  []  2021
# 11                                  []  2019
# 12                                  []  2019
# 13                                  []  2020
# 14                                  []  2019
# 15                                  []  2019
# 16                                  []  2019
# 17                                  []  2022
# 18                                  []  2020
# 19                                  []  2021
# 20                                  []  2019
# 21                                  []  2021
# 22                                  []  2021
# 23                                  []  2020
# 24  [https://openalex.org/W4205903454]  2021
#
#                                               journal  \
# 0                                             Science
# 1                        Journal of Business Research
# 2                        Auerbach Publications eBooks
# 3             Journal of Computer Information Systems
# 4   Journal of Strategic Innovation and Sustainabi...
# 5                   Uncertain Supply Chain Management
# 6      Computer Applications in Engineering Education
# 7         Technological Forecasting and Social Change
# 8        International Journal of Production Research
# 9                                           Logistics
# 10  International Journal of Contemporary Hospital...
# 11           Digital Policy Regulation and Governance
# 12  Eduzone International peer reviewed/refereed a...
# 13                                        IEEE Access
# 14  International Journal of Engineering and Advan...
# 15                                               JAMA
# 16              Zeitschrift für Tourismuswissenschaft
# 17                       Journal of Business Research
# 18      Journal of Hospitality and Tourism Technology
# 19          International Journal of Emerging Markets
# 20               Journal of Physics Conference Series
# 21           Journal of Global Information Management
# 22  International Journal of Advances in Soft Comp...
# 23                                        IEEE Access
# 24                            Artificial intelligence
#
#                                              keywords  \
# 0   [{'id': 'https://openalex.org/keywords/lying',...
# 1   [{'id': 'https://openalex.org/keywords/scienti...
# 2                                                  []
# 3   [{'id': 'https://openalex.org/keywords/generat...
# 4                                                  []
# 5                                                  []
# 6   [{'id': 'https://openalex.org/keywords/investm...
# 7   [{'id': 'https://openalex.org/keywords/sales-f...
# 8   [{'id': 'https://openalex.org/keywords/dynamic...
# 9                                                  []
# 10  [{'id': 'https://openalex.org/keywords/market-...
# 11  [{'id': 'https://openalex.org/keywords/value',...
# 12  [{'id': 'https://openalex.org/keywords/mass-cu...
# 13  [{'id': 'https://openalex.org/keywords/comprom...
# 14  [{'id': 'https://openalex.org/keywords/digitiz...
# 15  [{'id': 'https://openalex.org/keywords/fluid-o...
# 16  [{'id': 'https://openalex.org/keywords/interac...
# 17  [{'id': 'https://openalex.org/keywords/scarcit...
# 18  [{'id': 'https://openalex.org/keywords/value',...
# 19  [{'id': 'https://openalex.org/keywords/custome...
# 20  [{'id': 'https://openalex.org/keywords/technol...
# 21  [{'id': 'https://openalex.org/keywords/social-...
# 22  [{'id': 'https://openalex.org/keywords/web-cra...
# 23  [{'id': 'https://openalex.org/keywords/demand-...
# 24  [{'id': 'https://openalex.org/keywords/relevan...
#
#                                                topics
# 0   [Anomaly Detection Techniques and Applications...
# 1   [Quality and Supply Management, Management and...
# 2           [Digital Economy and Work Transformation]
# 3   [AI in Service Interactions, Artificial Intell...
# 4   [Internet of Things and AI, Blockchain Technol...
# 5   [Quality and Supply Management, Digital Transf...
# 6   [Smart Systems and Machine Learning, Big Data ...
# 7   [Evolutionary Algorithms and Applications, Mar...
# 8   [Big Data and Business Intelligence, Consumer ...
# 9   [Smart Agriculture and AI, Food Supply Chain T...
# 10  [Private Equity and Venture Capital, Digital M...
# 11  [Consumer Retail Behavior Studies, Technology ...
# 12                    [Fashion and Cultural Textiles]
# 13  [Blockchain Technology Applications and Securi...
# 14               [Big Data and Business Intelligence]
# 15  [Obesity, Physical Activity, Diet, Nutritional...
# 16  [AI in Service Interactions, Sharing Economy a...
# 17  [Consumer Retail Behavior Studies, Consumer Be...
# 18  [Digital Marketing and Social Media, Diverse A...
# 19  [AI in Service Interactions, Digital Marketing...
# 20            [E-commerce and Technology Innovations]
# 21  [Digital Marketing and Social Media, Consumer ...
# 22  [Advanced Malware Detection Techniques, Spam a...
# 23  [Smart Grid Energy Management, Energy Load and...
# 24                                                 []

# %%
# Save to CSV
# You might need to change the path 
dionne_path = "/Users/dionnespaltman/Desktop/Luiss /Data Science in Action/Project/openalex_papers.csv"
df.to_csv(dionne_path, index=False)

print("Extracted", len(df), "papers and saved them to 'openalex_papers.csv'.")
# Out:
# Extracted 25 papers and saved them to 'openalex_papers.csv'.
